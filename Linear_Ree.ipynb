# %%
# Basic packages used in the plots. 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")
colors = ["tab:blue","tab:red","tab:orange","tab:green","tab:purple", "tab:pink",
          "tab:olive", "tab:gray", "tab:brown"] #colors used by the plots
colors_dashed = ["lightseagreen","salmon","purple","olive"]
size = 28 #font size for some plots

# %%
df=pd.read_csv("./data_reeM.csv", sep = ";")
pd.unique(df["Material"])
# Out:
# array(['Sandstone', 'Ore', 'Oven Slag', 'Smithing Slag', 'Plate Slag',
#        'Flow Slag', 'Bloom', 'Iron-SI', 'Iron-SI-P'], dtype=object)

# %%
#Selection and lop to create the list of elements in the plot
list(df.columns)
elements = list(df.columns) 
elements.remove("Material")
elements.remove("Sample")
elements.remove("Site")


ele = []
for e in elements:
        ele.append(e)
         
elements=ele

# %%
# First plot and area of test. 

fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(df, cols = elements, class_column = "Material", ax = ax, color = colors,
                             linewidth=2.5, markersize=1)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=20)
#plt.title('REE LA-ICP-MS',fontsize=16)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(loc='upper right', fontsize=18)

# %%
#Full data plot
fig, ax = plt.subplots(1, figsize=(15,10))


pd.plotting.parallel_coordinates(df, cols = elements, class_column = "Material", ax = ax, color = colors,
                             linewidth=2.5, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=14)
plt.title('REE LA-ICP-MS',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12.5)

# %%
print(df["Material"].unique())
# Out:
# ['Sandstone' 'Ore' 'Oven Slag' 'Smithing Slag' 'Plate Slag' 'Flow Slag'
#  'Bloom' 'Iron-SI' 'Iron-SI-P']

# %%
#Plots using mask to select by materials 
mask1 = (df["Material"] != "Sandstone") 
mask2 = (df["Material"] == "Oven Slag") | (df["Material"] == "Plate Slag") | (df["Material"] == "Flow Slag")
mask3 = (df["Material"] == "Bloom") | (df["Material"] ==  "Iron-SI")

fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(df[mask1], cols = elements, class_column = "Material", ax = ax, color = colors
                                 , linewidth=2.5, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=14)
plt.title('REE LA-ICP-MS',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12.5)
plt.tight_layout()
fig.savefig("./plot2/full-smiting.png", dpi=200)

# %%
# Slag plot
mask1 = (df["Material"] == "Ore") | (df["Material"] == "Sandstone") | (df["Material"] == "Bloom")
mask2 = (df["Material"] == "Oven Slag") | (df["Material"] ==  "Plate Slag")| (df["Material"] ==  "Flow Slag")| (df["Material"] ==  "Smithing Slag")  


fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(df.loc[mask2], cols = elements, class_column = "Material", ax = ax, color= colors,
                                 linewidth=3, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=14)
plt.title('Slags by type',fontsize=20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12.5)
plt.tight_layout()
fig.savefig("./plot2/slags_type.png", dpi=200)

# %%
# Ore, blom and Iron plot
mask1 = (df["Material"] == "Ore") | (df["Material"] == "Sandstone") | (df["Material"] == "Bloom")
mask2 = (df["Material"] == "Oven Slag") | (df["Material"] == "Plate Slag") | (df["Material"] == "Flow Slag")
mask3 = (df["Material"] == "Bloom") | (df["Material"] ==  "Iron-SI")| (df["Material"] ==  "Iron-SI-P")

fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(df[mask3], cols = elements, class_column = "Material", ax = ax, color = colors
                                 , linewidth=3, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)

plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Bloom and SI',fontsize=20)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.legend(loc='upper right', fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/iron_ree.png", dpi=200)

# %%
# Ore, blom and Iron plot
mask1 = (df["Material"] == "Ore") | (df["Material"] == "Sandstone") | (df["Material"] == "Bloom")
mask2 = (df["Material"] == "Oven Slag") | (df["Material"] == "Plate Slag") | (df["Material"] == "Flow Slag")
mask3 = (df["Material"] == "Bloom") | (df["Material"] ==  "Iron-SI") | (df["Material"] ==  "Iron-SI-P")| (df["Material"] == "Oven Slag") |  (df["Material"] == "Plate Slag") | (df["Material"] == "Flow Slag")
fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(df[mask3], cols = elements, class_column = "Material", ax = ax, color = colors
                                 , linewidth=3, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)

plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Bloom and SI',fontsize=20)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.legend(loc='upper right', fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/iron_slag_ree.png", dpi=200)

# %%
print(df["Site"].unique())
# Out:
# ['Eisenberg' 'Imsbach' 'Hettenleidelheim' 'Tiefenthal' 'Stumpfwald']

# %%
#Ores by site
mask0 = (df["Material"] == "Ore")
fig, ax = plt.subplots(1, figsize=(15,10))


pd.plotting.parallel_coordinates(df[mask0], cols = elements, class_column = "Site", ax = ax, color = colors
                                 , linewidth=3, markersize=8)
plt.yscale("log")
plt.ylim(10**0.25,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Ores by Site LA-ICP-MS Results',fontsize=20)
ax.legend(loc='upper right', fontsize=size)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.legend(loc='upper right', fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/ores_site.png", dpi=200)

# %%
print(elements)
# Out:
# ['Th', 'U', 'Y', 'La', 'Ce', 'Pr', 'Nd', 'Sm', 'Eu', 'Gd', 'Dy', 'Er', 'Yb']

# %%
# new df to have mean, min and maximun values 
result = df.groupby('Material').agg({e: ['mean', 'min', 'max'] for e in elements})
result = result.stack(level = 1).reset_index().rename(columns = {"level_1": "type"})
result
# Out:
#          Material  type          Th            U           Y          La  \
# 0           Bloom  mean  195.403333  1472.973333   29.703333   86.216667
# 1           Bloom   min  175.860000  1364.860000   27.580000   80.170000
# 2           Bloom   max  227.590000  1567.570000   33.890000   91.980000
# 3       Flow Slag  mean  245.209091   711.167273   24.080000   98.609091
# 4       Flow Slag   min  155.410000   164.010000    8.680000   57.600000
# 5       Flow Slag   max  332.490000  2209.930000   42.670000  129.990000
# 6         Iron-SI  mean  237.470000   873.423333   43.886667  176.063333
# 7         Iron-SI   min  177.240000   179.730000   23.920000  107.850000
# 8         Iron-SI   max  322.760000  1264.860000   65.890000  255.190000
# 9       Iron-SI-P  mean  155.345000   444.257500   18.532500   88.997500
# 10      Iron-SI-P   min  123.100000   152.700000    9.090000   75.060000
# 11      Iron-SI-P   max  185.520000   728.380000   28.890000  115.440000
# ...

# %%
mask1 = (df["Material"] == "Ore") | (df["Material"] == "Sandstone") | (df["Material"] == "Bloom") | (df["Material"] == "Oven Slag") | (df["Material"] == "Plate Slag") | (df["Material"] == "Flow Slag") | (df["Material"] ==  "Iron-SI")
mask2_1 = (result["Material"] == "Oven Slag") | (result["Material"] == "Plate Slag") |(result["Material"] == "Flow Slag") |(result["Material"] == "Smithing Slag")
mask3 = (result["type"] != "mean") 


fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(result[mask3], cols = elements, class_column = "Material", ax = ax, 
                                 color=colors, linewidth=2.8, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=15)
plt.title('All Materials (Max & Min)',fontsize=20)
ax.legend(loc='upper right', fontsize=12.5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
fig.savefig("./plot2/full_mm.png", dpi=200)

# %%
maskmean = (result["type"] == "mean") 

fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(result[maskmean], cols = elements, class_column = "Material", ax = ax, 
                                 color= colors, linewidth=3, markersize=10)
plt.yscale("log")
plt.ylim(10**0.25,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=15)
plt.title('REE LA-ICP-MS Results (Mean)',fontsize=20)
ax.legend(loc='upper right', fontsize=12.5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.tight_layout()
fig.savefig("./plot2/full_mm.png", dpi=200)

# %%
mask2_1 =  (result["Material"] ==  "Iron-SI-P") | (result["Material"] ==  "Iron-SI-P")| (result["Material"] ==  "Iron-SI-P") | (result["Material"] == "Bloom") |(result["Material"] ==  "Iron-SI") | (result["Material"] == "Oven Slag") | (result["Material"] == "Plate Slag")| (result["Material"] == "Flow Slag")  

labels = ['Oven Slag', 'Smithing Slag', 'Plate Slag','Flow Slag', 'Bloom', 'Iron-SI', 'Iron-SI-P'] 

fig, ax = plt.subplots(1, figsize=(15,10))

pd.plotting.parallel_coordinates(result[mask2_1], cols = elements, class_column = "Material", ax = ax, color=colors
                                 , linewidth=3, markersize=8)
plt.yscale("log")
plt.ylim(10**0.1,10**4.2)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Slag by type (Max, Mean & Min)',fontsize=20)
ax.legend(loc='upper right', fontsize=size)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/slag+iron.png", dpi=200)

# %%
#New data frame from the df and results 
df1 = df.loc[(df["Material"]=="Ore")]
df2 = result.loc[(result["Material"].isin(["Iron-SI","Iron-SI-P", "Bloom", "Flow Slag", "Oven Slag", "Plate Slag", "Smithing Slag"])) & (result["type"] == "mean") ]

# %%
# append process to create a new data frame conving the two previus 
df_lines = df1.append(df2,ignore_index=True).fillna("")
df_lines
# Out:
#          Material     Sample              Site          Th            U  \
# 0             Ore  MA-200975         Eisenberg  178.920000   221.670000
# 1             Ore  MA-200977         Eisenberg  127.880000   297.460000
# 2             Ore  MA-201429           Imsbach  131.030000  9324.320000
# 3             Ore  MA-201430  Hettenleidelheim  141.380000   554.050000
# 4             Ore  MA-201431  Hettenleidelheim   52.070000   345.950000
# 5             Ore  MA-201432  Hettenleidelheim  110.340000   245.950000
# 6             Ore  MA-201433        Tiefenthal   92.070000   404.050000
# 7             Ore  MA-201434        Tiefenthal  186.210000   372.970000
# 8             Ore  MA-201535         Eisenberg   70.990000   533.720000
# 9             Ore  MA-201912  Hettenleidelheim  140.800000   600.460000
# 10            Ore  MA-201914        Stumpfwald   91.180000   275.310000
# 11          Bloom                               195.403333  1472.973333
# ...

# %%
# final plot using the new data frame convining samples by materail and samples by site (Ores)
mask1 = (df_lines["Material"] == "Ore")
mask2 = (df_lines["Material"] != "Ore" ) 
#ores = {"Eisenberg": "red", "Imbasch": "yellow", "Hettenleidelheim": "cyan","Tiefenthal": "purple", "Stupfwald": "green" }

#elements_sig = list(df_lines[elements].max()[df[elements].max() > 0.25].index)
fig, ax = plt.subplots(1, figsize=(15,10))


pd.plotting.parallel_coordinates(df_lines[mask2], cols = elements, class_column = "Material", ax = ax, color=colors,
                             linewidth=3, markersize=1)

pd.plotting.parallel_coordinates(df_lines[mask1], cols = elements, class_column = "Site", ax = ax, colormap = "brg",
                             linewidth=3,linestyle = "dashed", markersize=1)
plt.yscale("log")
plt.ylim(10**0.25,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=20)
plt.title('Rare Earth Elements  Results',fontsize=25)
ax.legend(loc='upper right', fontsize=12.5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.tight_layout()
fig.savefig("./plot2/full-ree-material-ore.png", dpi=200)

# %%
mask1 =  (df_lines["Site"] == "Imsbach") | (df_lines["Material"] == "Oven Slag") | (df_lines["Material"] == "Smithing Slag")|(df_lines["Material"] == "Flow Slag")  |(df_lines["Material"] == "Plate Slag")      
mask2 = (df_lines["Site"] == "Imsbach") | (df_lines["Material"] == "Bloom") | (df_lines["Material"] == "Iron-SI")| (df_lines["Material"] == "Iron-SI-P")

df_lines2 = df_lines.drop(index = df_lines.loc[mask1].index).reset_index(drop = True)
df_lines3 = df_lines.drop(index = df_lines.loc[mask2].index).reset_index(drop = True)
df_lines3
# Out:
#          Material     Sample              Site          Th           U  \
# 0             Ore  MA-200975         Eisenberg  178.920000  221.670000
# 1             Ore  MA-200977         Eisenberg  127.880000  297.460000
# 2             Ore  MA-201430  Hettenleidelheim  141.380000  554.050000
# 3             Ore  MA-201431  Hettenleidelheim   52.070000  345.950000
# 4             Ore  MA-201432  Hettenleidelheim  110.340000  245.950000
# 5             Ore  MA-201433        Tiefenthal   92.070000  404.050000
# 6             Ore  MA-201434        Tiefenthal  186.210000  372.970000
# 7             Ore  MA-201535         Eisenberg   70.990000  533.720000
# 8             Ore  MA-201912  Hettenleidelheim  140.800000  600.460000
# 9             Ore  MA-201914        Stumpfwald   91.180000  275.310000
# 10      Flow Slag                               245.209091  711.167273
# 11      Oven Slag                               237.246000  578.594000
# ...

# %%
# final plot using the new data frame convining samples by materail and samples by site (Ores)
mask1 = (df_lines2["Material"] == "Ore")
mask2 = (df_lines2["Material"] != "Ore" ) 
size = 22
fig, ax = plt.subplots(1, figsize=(15,10))


pd.plotting.parallel_coordinates(df_lines2[mask2], cols = elements, class_column = "Material", ax = ax, color = colors,
                             linewidth=3.5, markersize=1)

pd.plotting.parallel_coordinates(df_lines2[mask1], cols = elements, class_column = "Sample", ax = ax, color = colors_dashed,
                             linewidth=3.5,linestyle = "dashed", markersize=1)
plt.yscale("log")
plt.ylim(10**0.25,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Materials (mean) & Ores by site',fontsize=22)
ax.legend(loc='upper right', fontsize=size)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/iron+ores.png", dpi=200)

# %%
# final plot using the new data frame convining samples by materail and samples by site (Ores)
mask1 = (df_lines3["Material"] == "Ore")
mask2 = (df_lines3["Material"] != "Ore" ) 
size = 22
fig, ax = plt.subplots(1, figsize=(15,10))


pd.plotting.parallel_coordinates(df_lines3[mask2], cols = elements, class_column = "Material", ax = ax, color = colors,
                             linewidth=3.5, markersize=1)

pd.plotting.parallel_coordinates(df_lines3[mask1], cols = elements, class_column = "Site", ax = ax, color = colors_dashed,
                             linewidth=3.5,linestyle = "dashed", markersize=1)
plt.yscale("log")
plt.ylim(10**0.25,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Materials (mean) & Ores by site',fontsize=22)
ax.legend(loc='upper right', fontsize=size)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/slags+ores.png", dpi=200)

# %%
df_lines2
# Out:
#      Material     Sample              Site          Th            U  \
# 0         Ore  MA-200975         Eisenberg  178.920000   221.670000
# 1         Ore  MA-200977         Eisenberg  127.880000   297.460000
# 2         Ore  MA-201430  Hettenleidelheim  141.380000   554.050000
# 3         Ore  MA-201431  Hettenleidelheim   52.070000   345.950000
# 4         Ore  MA-201432  Hettenleidelheim  110.340000   245.950000
# 5         Ore  MA-201433        Tiefenthal   92.070000   404.050000
# 6         Ore  MA-201434        Tiefenthal  186.210000   372.970000
# 7         Ore  MA-201535         Eisenberg   70.990000   533.720000
# 8         Ore  MA-201912  Hettenleidelheim  140.800000   600.460000
# 9         Ore  MA-201914        Stumpfwald   91.180000   275.310000
# 10      Bloom                               195.403333  1472.973333
# 11    Iron-SI                               237.470000   873.423333
# 12  Iron-SI-P                               155.345000   444.257500
#
# ...

# %%
df1
# Out:
#    Material     Sample              Site      Th        U       Y      La  \
# 1       Ore  MA-200975         Eisenberg  178.92   221.67   16.42   57.20
# 3       Ore  MA-200977         Eisenberg  127.88   297.46   34.00  130.89
# 44      Ore  MA-201429           Imsbach  131.03  9324.32  124.84  113.50
# 45      Ore  MA-201430  Hettenleidelheim  141.38   554.05   11.91   59.07
# 46      Ore  MA-201431  Hettenleidelheim   52.07   345.95    8.47   25.74
# 47      Ore  MA-201432  Hettenleidelheim  110.34   245.95    8.22   33.33
# 48      Ore  MA-201433        Tiefenthal   92.07   404.05   18.54   33.33
# 49      Ore  MA-201434        Tiefenthal  186.21   372.97   22.93  108.86
# 50      Ore  MA-201535         Eisenberg   70.99   533.72   23.08   91.40
# 51      Ore  MA-201912  Hettenleidelheim  140.80   600.46    6.85   32.81
# 52      Ore  MA-201914        Stumpfwald   91.18   275.31    8.88   21.41
#
#        Ce      Pr      Nd      Sm     Eu      Gd      Dy      Er     Yb
# ...

# %%
# final plot using the new data frame convining samples by materail and samples by site (Ores)
maskO =(df_lines["Sample"] == "MA-200975") | (df_lines["Sample"] == "MA-201430") | (df_lines["Sample"] == "MA-201431") | (df_lines["Sample"] == "MA-201434")

mask1 = (df_lines["Material"] == "Ore")
mask2 = (df_lines["Material"] == "Bloom" ) | (df_lines["Material"] == "Iron-SI" ) | (df_lines["Material"] == "Oven Slag" )  | (df_lines["Material"] == "Plate Slag" ) 
size = 22
fig, ax = plt.subplots(1, figsize=(15,10))


pd.plotting.parallel_coordinates(df_lines[mask2], cols = elements, class_column = "Material", ax = ax, color = colors,
                             linewidth=3.5, markersize=1)

pd.plotting.parallel_coordinates(df_lines[maskO], cols = elements, class_column = "Sample", ax = ax, color = colors_dashed,
                             linewidth=3.5,linestyle = "dashed", markersize=1)
plt.yscale("log")
plt.ylim(10**0.25,10**4.5)
plt.ylabel('REE$_{sample}$/REE$_{Chondrite}$', fontsize=size)
#plt.title('Materials (mean) & Ores by site',fontsize=22)
ax.legend(loc='upper right', fontsize=size)
plt.xticks(fontsize=size)
plt.yticks(fontsize=size)
plt.tight_layout()
fig.savefig("./plot2/final_results.png", dpi=200)
